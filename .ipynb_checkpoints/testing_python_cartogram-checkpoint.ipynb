# %%
import numpy as np
import shapely
import geopandas as gpd
import pandas as pd
from shapely.geometry import Polygon
from shapely.geometry import shape

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
print(world.shape)
world.plot()
# Out:
# (177, 6)
# <AxesSubplot:>

# %%
arg_polygons=world.geometry
arg_polygons
# Out:
# 0      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1      POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2      POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3      MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4      MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#                              ...
# 172    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173    POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175    POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176    POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
# Name: geometry, Length: 177, dtype: geometry

# %%
exploded = world.explode()
print(exploded.shape)
exploded.plot()
# Out:
# (288, 6)
# <AxesSubplot:>

# %% [markdown]
# Unfortunately, then running the PyCartogram code on this exploded GeoDataFrame results is the following warning:
# > ValueError: A LinearRing must have at least 3 coordinate tuples
# The implication is that there is something duff that needs to be fixed in process of exploding.

# %%
item0=exploded.iat[0,5]
print(item0)
# Out:
# POLYGON ((180 -16.06713266364245, 180 -16.5552165666392, 179.3641426619641 -16.80135407694688, 178.7250593629971 -17.01204167436804, 178.5968385951171 -16.63915, 179.0966093629971 -16.4339842775474, 179.4135093629971 -16.3790542775474, 180 -16.06713266364245))

# %%
#Check Geometry
def npts(geom):
    LinRing=geom.exterior
    coords=LinRing.coords
    num_points=len(coords)
    return num_points

exploded['npts'] = exploded['geometry'].apply(lambda x: npts(x))
exploded['npts'].min()
# Out:
# 4

# %% [markdown]
# There is a function written by JoeryJoery that will update the polygons of a GeoSeries in contiguous area form. It's available at <https://github.com/joeryjoery/PyCartogram>. I'm copying it below

# %%
def cartogram(arg_polygons, arg_values, itermax=5, max_size_error=1.0001, epsilon=0.01, verbose=False):
    """
    Generate an area equalizing contiguous cartogram based on the algorithm by (J. Oougenik et al., 1985).
    
    Note: The current function does not include interior boundaries when distorting the polygons!
          This is due to shapely's current way of extracting boundary coordinates which make it 
          cumbersome to separate interior points from exterior points.
    
    :param arg_polygons: geopandas.geoseries.GeoSeries Series of shapely.geometry.Polygon or Multipolygon objects.
    :param arg_values: (geo)pandas.Series Series of floating point values.
    :param itermax: int (Optional, default=5) Maximum amount of iterations to perform adjusting coordinates.
    :param max_size_error: float (Optional, default=1.0001) A maximum accuracy until terminating the procedure.
    :param epsilon: float (Optional, default=0.01) Scalar to prevent zero division errors.
    :param verbose: bool (Optional, default=False) Whether to print out intermediary progress. 
    
    :returns: geopandas.geoseries.GeoSeries Copy of :arg_polygons: with the adjusted coordinates.
    
    :references: Dougenik, J.A., Chrisman, N.R. and Niemeyer, D.R. (1985), 
                 AN ALGORITHM TO CONSTRUCT CONTINUOUS AREA CARTOGRAMS*. 
                 The Professional Geographer, 37: 75-81. doi:10.1111/j.0033-0124.1985.00075.x 
    
    :see: Implementation of the same algorithm in R (available on CRAN): https://github.com/sjewo/cartogram
    """    
    
    arg_polygons.to_crs('+proj=cea')
    geometry = arg_polygons.copy().values
    values = arg_values.copy().values
    
    total_value = values.sum()
    mean_size_error = 100
    
    for iteration in range(itermax):
        if mean_size_error < max_size_error:
            break
        
        # This statement unpacks the centroid Point object to np.array and
        # creates a n x 2 matrix of centroid [x, y] coordinates.
        centroids = np.array(list(map(np.array, geometry.to_crs('+proj=cea').centroid.to_crs(geometry.crs))))
        area = geometry.to_crs('+proj=cea').area
        total_area = area.sum()
        
        desired = total_area * values / total_value
        desired[desired == 0] = epsilon  # Prevent zero division.
        radius = np.sqrt(area / np.pi)
        mass = np.sqrt(desired / np.pi) - np.sqrt(area / np.pi)
        
        size_error = np.max([desired, area], axis=0) - np.min([desired, area], axis=0)
        mean_size_error = np.mean(size_error)
        force_reduction_factor = 1 / (1 + mean_size_error)
        
        if verbose:
            print("Mean size error at iteration {}: {}".format(iteration+1, mean_size_error))
        for row, item in enumerate(geometry):
            print(row)
            # TODO: Possibly include shapely.geometry.Polygon interior coordinates.
            
            # Some coordinates may appear twice, however, they mustn't be removed.
            # These coordinates are also adjusted, but only computed once:
            coordinates = np.matrix(item.exterior.coords)    # [[x1, y2], [x2, y2], ...]
            idx = np.unique(coordinates, axis=0)                # Get unique rows
            
            for k in range(len(idx)):
                # Get positions from coordinates for each unique idx.
                coord_idx = np.where((coordinates[:, 0] == idx[k,0]) & (coordinates[:,1] == idx[k, 1]))[0]
                # Only extract one using coord_idx[0] as coord_idx maps duplicate coordinates.
                new_coordinates = coordinates[coord_idx[0],:]  

                # Compute coordinate's euclidean distances to all centroids.
                distances = np.sqrt(np.square(centroids - new_coordinates).sum(axis=1))
                distances = np.array(distances).ravel()  # Converts matrix into flat array.
                
                # Compute force vectors
                Fijs = mass * radius / distances
                Fbij = mass * np.square(distances / radius) * (4 - 3 * distances / radius)
                Fijs[distances <= radius] = Fbij[distances <= radius]
                Fijs *= force_reduction_factor / distances
                
                # Find how much "force" must be applied to the coordinates by computing
                # the dot product of the force vector and the centroid deltas.
                new_coordinates += Fijs.dot(new_coordinates - centroids)

            # Set the polygon 
            geometry[row] = Polygon(coordinates, holes = item.interiors)
            
    return gpd.geoseries.GeoSeries(geometry)

# %%
exploded.to_crs('+proj=cea')
pop_cart=cartogram(exploded['geometry'], exploded['pop_est'])
# Out:
# /home/ucfaccb/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/ucfaccb/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
def cartogram(arg_polygons, arg_values, itermax=5, max_size_error=1.0001, epsilon=0.01, verbose=False):
    """
    Generate an area equalizing contiguous cartogram based on the algorithm by (J. Oougenik et al., 1985).
    
    Note: The current function does not include interior boundaries when distorting the polygons!
          This is due to shapely's current way of extracting boundary coordinates which make it 
          cumbersome to separate interior points from exterior points.
    
    :param arg_polygons: geopandas.geoseries.GeoSeries Series of shapely.geometry.Polygon objects.
    :param arg_values: (geo)pandas.Series Series of floating point values.
    :param itermax: int (Optional, default=5) Maximum amount of iterations to perform adjusting coordinates.
    :param max_size_error: float (Optional, default=1.0001) A maximum accuracy until terminating the procedure.
    :param epsilon: float (Optional, default=0.01) Scalar to prevent zero division errors.
    :param verbose: bool (Optional, default=False) Whether to print out intermediary progress. 
    
    :returns: geopandas.geoseries.GeoSeries Copy of :arg_polygons: with the adjusted coordinates.
    
    :references: Dougenik, J.A., Chrisman, N.R. and Niemeyer, D.R. (1985), 
                 AN ALGORITHM TO CONSTRUCT CONTINUOUS AREA CARTOGRAMS*. 
                 The Professional Geographer, 37: 75-81. doi:10.1111/j.0033-0124.1985.00075.x 
    
    :see: Implementation of the same algorithm in R (available on CRAN): https://github.com/sjewo/cartogram
    """    
    polygons = arg_polygons.copy().values
    values = arg_values.copy().values
    
    total_value = values.sum()
    mean_size_error = 100
    
    for iteration in range(itermax):
        if mean_size_error < max_size_error:
            break
        
        # This statement unpacks the centroid Point object to np.array and
        # creates a n x 2 matrix of centroid [x, y] coordinates.
        centroids = np.array(list(map(np.array, polygons.centroid)))
        area = polygons.area
        total_area = area.sum()
        
        desired = total_area * values / total_value
        desired[desired == 0] = epsilon  # Prevent zero division.
        radius = np.sqrt(area / np.pi)
        mass = np.sqrt(desired / np.pi) - np.sqrt(area / np.pi)
        
        size_error = np.max([desired, area], axis=0) - np.min([desired, area], axis=0)
        mean_size_error = np.mean(size_error)
        force_reduction_factor = 1 / (1 + mean_size_error)
        
        if verbose:
            print("Mean size error at iteration {}: {}".format(iteration+1, mean_size_error))
        for row, polygon in enumerate(polygons):
            
            # TODO: Possibly include shapely.geometry.Polygon interior coordinates.
            
            # Some coordinates may appear twice, however, they mustn't be removed.
            # These coordinates are also adjusted, but only computed once:
            coordinates = np.matrix(polygon.exterior.coords)    # [[x1, y2], [x2, y2], ...]
            idx = np.unique(coordinates, axis=0)                # Get unique rows
            
            for k in range(len(idx)):
                # Get positions from coordinates for each unique idx.
                coord_idx = np.where((coordinates[:, 0] == idx[k,0]) & (coordinates[:,1] == idx[k, 1]))[0]
                # Only extract one using coord_idx[0] as coord_idx maps duplicate coordinates.
                new_coordinates = coordinates[coord_idx[0],:]  
                
                # Compute coordinate's euclidean distances to all centroids.
                distances = np.sqrt(np.square(centroids - new_coordinates).sum(axis=1))
                distances = np.array(distances).ravel()  # Converts matrix into flat array.
                
                # Compute force vectors
                Fijs = mass * radius / distances
                Fbij = mass * np.square(distances / radius) * (4 - 3 * distances / radius)
                Fijs[distances <= radius] = Fbij[distances <= radius]
                Fijs *= force_reduction_factor / distances
                
                # Find how much "force" must be applied to the coordinates by computing
                # the dot product of the force vector and the centroid deltas.
                new_coordinates += Fijs.dot(new_coordinates - centroids)
                
            # Set the polygon 
            polygons[row] = Polygon(coordinates, holes = polygon.interiors)
            
    return gpd.geoseries.GeoSeries(polygons)

# %%
exploded = world.explode()
exploded.to_crs('+proj=cea')
exploded
# Out:
#         pop_est      continent                 name iso_a3  gdp_md_est  \
# 0   0    920938        Oceania                 Fiji    FJI      8374.0
#     1    920938        Oceania                 Fiji    FJI      8374.0
#     2    920938        Oceania                 Fiji    FJI      8374.0
# 1   0  53950935         Africa             Tanzania    TZA    150600.0
# 2   0    603253         Africa            W. Sahara    ESH       906.5
# ...         ...            ...                  ...    ...         ...
# 172 0   7111024         Europe               Serbia    SRB    101800.0
# 173 0    642550         Europe           Montenegro    MNE     10610.0
# 174 0   1895250         Europe               Kosovo    -99     18490.0
# 175 0   1218208  North America  Trinidad and Tobago    TTO     43570.0
# 176 0  13026129         Africa             S. Sudan    SSD     20880.0
#
#                                                 geometry
# 0   0  POLYGON ((180.00000 -16.06713, 180.00000 -16.5...
#     1  POLYGON ((178.12557 -17.50481, 178.37360 -17.3...
#     2  POLYGON ((-179.79332 -16.02088, -179.91737 -16...
# 1   0  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2   0  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# ...                                                  ...
# 172 0  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173 0  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174 0  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175 0  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176 0  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
# [288 rows x 6 columns]

# %%
pop_cart=cartogram(exploded['geometry'], exploded['pop_est'],itermax=100,verbose=True)
pop_cart[0]
# Out:
# /home/ucfaccb/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/ucfaccb/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Mean size error at iteration 1: 108.87967490636228
# Mean size error at iteration 2: 108.1330970377757
# Mean size error at iteration 3: 107.37641434897584
# Mean size error at iteration 4: 106.62401579630108
# Mean size error at iteration 5: 105.87550496974242
# Mean size error at iteration 6: 105.13089618821985
# Mean size error at iteration 7: 104.39023594819955
# Mean size error at iteration 8: 103.65657705856438
# Mean size error at iteration 9: 102.92795806504805
# Mean size error at iteration 10: 102.20347832604742
# Mean size error at iteration 11: 101.48461082481735
# Mean size error at iteration 12: 100.77001181697386
# Mean size error at iteration 13: 100.05957080403401
# Mean size error at iteration 14: 99.35348391945293
# Mean size error at iteration 15: 98.65169715979967
# Mean size error at iteration 16: 97.95479060221255
# Mean size error at iteration 17: 97.26210143456018
# Mean size error at iteration 18: 96.57364255361253
# Mean size error at iteration 19: 95.88943637770964
# Mean size error at iteration 20: 95.20950696149728
# Mean size error at iteration 21: 94.53387919330359
# Mean size error at iteration 22: 93.86257709068059
# Mean size error at iteration 23: 93.19595994170196
# Mean size error at iteration 24: 92.53383952550887
# Mean size error at iteration 25: 91.87614974636628
# Mean size error at iteration 26: 91.22347684962233
# Mean size error at iteration 27: 90.57825579013974
# Mean size error at iteration 28: 89.93844757319465
# Mean size error at iteration 29: 89.30305053108684
# Mean size error at iteration 30: 88.67207683507864
# Mean size error at iteration 31: 88.04553702892878
# Mean size error at iteration 32: 87.42477715008322
# Mean size error at iteration 33: 86.80853851329013
# Mean size error at iteration 34: 86.19673707948321
# Mean size error at iteration 35: 85.58953836086198
# Mean size error at iteration 36: 84.98682240121434
# Mean size error at iteration 37: 84.38857065662377
# Mean size error at iteration 38: 83.79474985785524
# Mean size error at iteration 39: 83.20766567294042
# Mean size error at iteration 40: 82.62650610368316
# Mean size error at iteration 41: 82.04970670234202
# Mean size error at iteration 42: 81.47726241988215
# Mean size error at iteration 43: 80.90916694591556
# Mean size error at iteration 44: 80.34556225592024
# Mean size error at iteration 45: 79.78720569930991
# Mean size error at iteration 46: 79.23315530668063
# Mean size error at iteration 47: 78.68339206544613
# Mean size error at iteration 48: 78.13789713717587
# Mean size error at iteration 49: 77.59665210852867
# Mean size error at iteration 50: 77.0596375887591
# Mean size error at iteration 51: 76.52683098220523
# Mean size error at iteration 52: 75.99820301114363
# Mean size error at iteration 53: 75.47372240470398
# Mean size error at iteration 54: 74.95335628674665
# Mean size error at iteration 55: 74.43706667989282
# Mean size error at iteration 56: 73.92485343662754
# Mean size error at iteration 57: 73.41675809180498
# Mean size error at iteration 58: 72.91262523880783
# Mean size error at iteration 59: 72.41242983163046
# Mean size error at iteration 60: 71.9162394922861
# Mean size error at iteration 61: 71.4238626437305
# Mean size error at iteration 62: 70.93524699382067
# Mean size error at iteration 63: 70.45033707495169
# Mean size error at iteration 64: 69.97670213024882
# Mean size error at iteration 65: 69.51037054223139
# Mean size error at iteration 66: 69.04755892087029
# Mean size error at iteration 67: 68.58818178057328
# Mean size error at iteration 68: 68.13216178206886
# Mean size error at iteration 69: 67.67942712338335
# Mean size error at iteration 70: 67.22990636882884
# Mean size error at iteration 71: 66.78353137978623
# Mean size error at iteration 72: 66.34023644263175
# Mean size error at iteration 73: 65.89996030117054
# Mean size error at iteration 74: 65.46264806466421
# Mean size error at iteration 75: 65.02824966590485
# Mean size error at iteration 76: 64.59712396069973
# Mean size error at iteration 77: 64.16908862050913
# Mean size error at iteration 78: 63.74382240791298
# Mean size error at iteration 79: 63.32128982082137
# Mean size error at iteration 80: 62.90145726640708
# Mean size error at iteration 81: 62.484482490146966
# Mean size error at iteration 82: 62.07016870433094
# Mean size error at iteration 83: 61.658487507441905
# Mean size error at iteration 84: 61.24971570661215
# Mean size error at iteration 85: 60.846327355675875
# Mean size error at iteration 86: 60.445542400198505
# Mean size error at iteration 87: 60.04733494954816
# Mean size error at iteration 88: 59.65176657615858
# Mean size error at iteration 89: 59.259007632779536
# Mean size error at iteration 90: 58.86872746642611
# Mean size error at iteration 91: 58.48088572685578
# Mean size error at iteration 92: 58.09543766464286
# Mean size error at iteration 93: 57.71232607849869
# Mean size error at iteration 94: 57.34810718654913
# Mean size error at iteration 95: 56.99147504333512
# Mean size error at iteration 96: 56.636765352035724
# Mean size error at iteration 97: 56.28391848516618
# Mean size error at iteration 98: 55.93287611968881
# Mean size error at iteration 99: 55.58550864698731
# Mean size error at iteration 100: 55.244437679221136

# %%
pop_cart.plot()
# Out:
# <AxesSubplot:>

# %%
#Check Geometry
def compute_area(geom):
    area = geom.area
    return area

world['area'] = world['geometry'].apply(lambda x: compute_area(x))
world['pop_dens']=world['pop_est']/world['area']
world['gdp_dens']=world['gdp_md_est']/world['area']
explode_me=world.drop(['pop_est','gdp_md_est','area'],axis=1)
exploded=explode_me.explode()
exploded['area'] = exploded['geometry'].apply(lambda x: compute_area(x))
exploded['pop']=exploded['pop_dens']*exploded['area']
exploded
# Out:
#            continent                 name iso_a3      pop_dens      gdp_dens  \
# 0   0        Oceania                 Fiji    FJI  5.617150e+05   5107.620517
#     1        Oceania                 Fiji    FJI  5.617150e+05   5107.620517
#     2        Oceania                 Fiji    FJI  5.617150e+05   5107.620517
# 1   0         Africa             Tanzania    TZA  7.070714e+05   1973.736886
# 2   0         Africa            W. Sahara    ESH  7.011322e+04    105.358166
# ...              ...                  ...    ...           ...           ...
# 172 0         Europe               Serbia    SRB  8.264098e+05  11830.717960
# 173 0         Europe           Montenegro    MNE  4.343548e+05   7172.211494
# 174 0         Europe               Kosovo    -99  1.538800e+06  15012.486235
# 175 0  North America  Trinidad and Tobago    TTO  1.906429e+06  68184.663537
# 176 0         Africa             S. Sudan    SSD  2.544359e+05    407.843519
#
#                                                 geometry       area  \
# 0   0  POLYGON ((180.00000 -16.06713, 180.00000 -16.5...   0.588778
#     1  POLYGON ((178.12557 -17.50481, 178.37360 -17.3...   0.983740
#     2  POLYGON ((-179.79332 -16.02088, -179.91737 -16...   0.066993
# 1   0  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...  76.301964
# 2   0  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...   8.603984
# ...                                                  ...        ...
# 172 0  POLYGON ((18.82982 45.90887, 18.82984 45.90888...   8.604719
# 173 0  POLYGON ((20.07070 42.58863, 19.80161 42.50009...   1.479321
# 174 0  POLYGON ((20.59025 41.85541, 20.52295 42.21787...   1.231641
# 175 0  POLYGON ((-61.68000 10.76000, -61.10500 10.890...   0.639000
# 176 0  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...  51.196106
#
#                 pop
# 0   0  3.307254e+05
#     1  5.525816e+05
#     2  3.763094e+04
# 1   0  5.395094e+07
# 2   0  6.032530e+05
# ...             ...
# 172 0  7.111024e+06
# 173 0  6.425500e+05
# 174 0  1.895250e+06
# 175 0  1.218208e+06
# 176 0  1.302613e+07
#
# [288 rows x 8 columns]

# %%
pop_cart=cartogram(exploded['geometry'], exploded['pop'],itermax=50,verbose=True)
print(pop_cart[0])
pop_cart.plot()
# Out:
# /home/ucfaccb/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/ucfaccb/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Mean size error at iteration 1: 94.86160029221742
# Mean size error at iteration 2: 94.1581429426216
# Mean size error at iteration 3: 93.4391656766557
# Mean size error at iteration 4: 92.72618341551103
# Mean size error at iteration 5: 92.01664753788788
# Mean size error at iteration 6: 91.31001861703407
# Mean size error at iteration 7: 90.60635919141143
# Mean size error at iteration 8: 89.90573372461095
# Mean size error at iteration 9: 89.20820667024832
# Mean size error at iteration 10: 88.5138431309614
# Mean size error at iteration 11: 87.8227093736827
# Mean size error at iteration 12: 87.1348717953572
# Mean size error at iteration 13: 86.45039687949763
# Mean size error at iteration 14: 85.7693515080861
# Mean size error at iteration 15: 85.09180424573303
# Mean size error at iteration 16: 84.41782294895496
# Mean size error at iteration 17: 83.74753773736113
# Mean size error at iteration 18: 83.08101875592314
# Mean size error at iteration 19: 82.41826012812514
# Mean size error at iteration 20: 81.75932907302432
# Mean size error at iteration 21: 81.10451831092847
# Mean size error at iteration 22: 80.4536740530462
# Mean size error at iteration 23: 79.80685941059195
# Mean size error at iteration 24: 79.16413930530818
# Mean size error at iteration 25: 78.5255761219343
# Mean size error at iteration 26: 77.89123018908052
# Mean size error at iteration 27: 77.26115874414005
# Mean size error at iteration 28: 76.63541178008336
# Mean size error at iteration 29: 76.01403218260835
# Mean size error at iteration 30: 75.39705680734575
# Mean size error at iteration 31: 74.7845180756679
# Mean size error at iteration 32: 74.1764433890283
# Mean size error at iteration 33: 73.57285602455137
# Mean size error at iteration 34: 72.9867982392866
# Mean size error at iteration 35: 72.42318236912243
# Mean size error at iteration 36: 71.86472509532108
# Mean size error at iteration 37: 71.31109182594993
# Mean size error at iteration 38: 70.7622717332681
# Mean size error at iteration 39: 70.21824612764948
# Mean size error at iteration 40: 69.67898943156837
# Mean size error at iteration 41: 69.14745116908836
# Mean size error at iteration 42: 68.6219125076255
# Mean size error at iteration 43: 68.10095007754981
# Mean size error at iteration 44: 67.58451858128147
# Mean size error at iteration 45: 67.07257122179661
# Mean size error at iteration 46: 66.56506523053554
# Mean size error at iteration 47: 66.0619622794548
# Mean size error at iteration 48: 65.56322776720849
# Mean size error at iteration 49: 65.06883028753872
# Mean size error at iteration 50: 64.57873984773082
# POLYGON ((175.1348635112793 -19.26877001067964, 175.1202169542336 -19.7649504666463, 174.4244331514537 -20.08717780080842, 173.7295331104262 -20.30441070602557, 173.6065888655594 -19.93125066345058, 174.1212066239533 -19.67458525833853, 174.5115568604455 -19.59062241493416, 175.2598420364938 -19.21883651324076, 175.258625156187 -19.21813936905415, 175.2574127333619 -19.21743172547328, 175.2562011431735 -19.21672706378911, 175.2549945283906 -19.21602433507198, 175.2537943071805 -19.21532351806215, 175.25260106644 -19.21462490447309, 175.2514153546679 -19.21392877104067, 175.2502376701787 -19.2132353716852, 175.2490684575987 -19.21254493930001, 175.247908127067 -19.21185769494957, 175.2467570582573 -19.21117385213301, 175.2456156003113 -19.21049361395425, 175.2444840749226 -19.20981716611807, 175.2433627812465 -19.20914468520223, 175.2422520021979 -19.20847634139079, 175.2411519175298 -19.207812338349, 175.2400627564443 -19.20715282568889, 175.2389848363158 -19.20649789395539, 175.237918380544 -19.20584768400558, 175.2368633268166 -19.20520250476505, 175.2358201689905 -19.20456232807347, 175.23478911993 -19.20392729266261, 175.2337703841616 -19.20329753934287, 175.2327641634619 -19.20267320853586, 175.2317706575706 -19.2020544380822, 175.2307900661497 -19.20144135705639, 175.2298225854583 -19.20083408635944, 175.2288684075063 -19.20023273915076, 175.2279277193607 -19.19963742442638, 175.227000704237 -19.19904824531987, 175.2260875399696 -19.19846530013808, 175.2251884031926 -19.19788868525438, 175.2242877249431 -19.19733107406458, 175.2233801558178 -19.1967979377967, 175.222487203421 -19.19627292455988, 175.2216094373629 -19.19575577409534, 175.2207470113636 -19.19524653640246, 175.2199000717209 -19.1947452539955, 175.219068757519 -19.1942519616107, 175.2182496566022 -19.19376987308736, 175.2174449690973 -19.19329731603832, 175.2166564700499 -19.1928328424735, 175.2158842507226 -19.19237645907055, 175.2151283900575 -19.19192816943969, 175.2143889471484 -19.19148797632152, 175.2136659649803 -19.19105588471089, 175.2129594711304 -19.19063189960294, 175.2122694759819 -19.19021603447247, 175.2115959723452 -19.18980831367868, 175.1348635112793 -19.26877001067964))
# <AxesSubplot:>

# %%
#exploded['geometry']=pop_cart
exploded['cart']=pop_cart
exploded.set_geometry('cart')
#print(exploded['pop'].values)
#print(pop_cart)

df = pd.DataFrame({'pop': exploded['pop'].values})
gdf = gpd.GeoDataFrame(df, geometry=pop_cart)
gdf.plot('pop', label=True)
# Out:
# <AxesSubplot:>
